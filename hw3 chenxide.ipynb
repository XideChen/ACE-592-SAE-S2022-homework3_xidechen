# %%
import glob
import pandas as pd
from econtools.metrics import reg
import numpy as np
import dask.dataframe as dd
from dask.distributed import Client, progress
#import multiprocess as mp
import matplotlib.pyplot as plt
import json
import dask
#import geopandas as gp
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt
from multiprocessing.pool import ThreadPool, Pool
from dask import delayed
from dask import compute

def haversine(row):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    lon1, lat1, lon2, lat2 = row
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# %% [markdown]
#  1.Read in every year of available data (2012 to 2020) using Dask

# %%
cd "C:\Users\fxx\Desktop\zuoye\ace 592 file"
# Out:
# C:\Users\fxx\Desktop\zuoye\ace 592 file

# %%
import pandas as pd

# %%
from dask.distributed import Client, progress
client = Client(n_workers=2, threads_per_worker=2, memory_limit='1GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:53136' processes=2 threads=4, memory=1.86 GiB>

# %%
t: year
i: exporter
j: importer
k: product
v: value 
q: quantity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 t: year
#       2 i: exporter
#       3 j: importer
#
# NameError: name 'year' is not defined

# %%
import dask
import dask.dataframe as dd

# %%
df = dd.read_csv("BACI_HS12_*.csv")
df
# Out:
# Dask DataFrame Structure:
#                     t      i      j      k        v        q
# npartitions=66
#                 int64  int64  int64  int64  float64  float64
#                   ...    ...    ...    ...      ...      ...
# ...               ...    ...    ...    ...      ...      ...
#                   ...    ...    ...    ...      ...      ...
#                   ...    ...    ...    ...      ...      ...
# Dask Name: read-csv, 66 tasks

# %%
df.head(5)
# Out:
#       t  i   j       k      v      q
# 0  2012  4   8  610469  2.734  0.044
# 1  2012  4   8  630900  0.110  0.082
# 2  2012  4  12   91099  1.185  1.200
# 3  2012  4  32  392630  1.286  0.123
# 4  2012  4  32  710310  0.095  0.004

# %%
def mean_t(df):
    df.t.mean()
def mean_i(df):
    df.i.mean()
def mean_j(df):
    df.j.mean()
def mean_k(df):
    df.k.mean()
def mean_v(df):
    df.v.mean()
def mean_q(df):
    df.q.mean()
mt = dask.delayed(mean_t).compute()
mi = dask.delayed(mean_i).compute()
mj = dask.delayed(mean_j).compute()
mk = dask.delayed(mean_k).compute()
mv = dask.delayed(mean_v).compute()
mq = dask.delayed(mean_q).compute()

df.npartitions
# Out:
# 66

# %%
df.partitions[5].compute()
type(df.partitions[5].compute())
df.known_divisions
df = df.set_index('t', sorted=True)
df = df.set_index('i', sorted=True)
df = df.set_index('j', sorted=True)
df = df.set_index('k', sorted=True)
df = df.set_index('v', sorted=True)
df = df.set_index('q', sorted=True)
# Out:
# 2022-04-27 13:10:20,808 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:10:41,881 - distributed.nanny - WARNING - Restarting worker
# 2022-04-27 13:11:54,342 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:54,450 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:54,552 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:54,664 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:54,754 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:54,836 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:54,952 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,053 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,138 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,251 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,337 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,452 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,567 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,638 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,753 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,862 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:55,939 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,069 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,139 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,268 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,340 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,455 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,559 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,659 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,756 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,838 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:56,954 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,065 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,142 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,250 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,344 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,439 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,554 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,639 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,754 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,840 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:57,954 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,039 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,156 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,256 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,340 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,455 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,540 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,655 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,756 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,852 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:58,962 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,043 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,157 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,257 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,342 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,457 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,545 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,652 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,747 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# 2022-04-27 13:11:59,841 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:11:59,959 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,042 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,153 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,261 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,358 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,461 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,565 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,660 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,755 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,861 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:00,960 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,062 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,142 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,253 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,344 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,454 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,549 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,644 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,755 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,865 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:01,941 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,048 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,139 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,252 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,344 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,445 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,578 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,648 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,734 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,851 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:02,938 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:03,039 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:03,158 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:03,244 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:03,360 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:03,446 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:12:03,677 - distributed.nanny - WARNING - Restarting worker
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, '拒绝访问。', None, 5, None)>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\process.py", line 32, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "D:\anaconda\ana\lib\multiprocessing\process.py", line 133, in terminate
#     self._popen.terminate()
#   File "D:\anaconda\ana\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] 拒绝访问。
# 2022-04-27 13:12:22,615 - distributed.nanny - WARNING - Worker process still alive after 3.999999237060547 seconds, killing
# Task exception was never retrieved
# future: <Task finished name='Task-943' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-941' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-779' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-831' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-935' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-952' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-856' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-923' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-926' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-818' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-875' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-837' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-871' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-810' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-913' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-761' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-927' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-863' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-889' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-891' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-823' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-793' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-780' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-901' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-833' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-884' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-806' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-908' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-904' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-777' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-916' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-839' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-766' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-893' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-890' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-882' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-870' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-796' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-917' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-854' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-832' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-897' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-781' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-817' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-767' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-807' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-850' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-798' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-881' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-838' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-864' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-790' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-829' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-774' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-900' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-815' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-801' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-958' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-949' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-956' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-932' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-930' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-938' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-928' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-946' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-936' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-954' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-944' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-933' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-951' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-942' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-931' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-950' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-940' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-929' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-957' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-947' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-937' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-955' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-945' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-934' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-878' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-803' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-920' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-860' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# ...
# future: <Task finished name='Task-876' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-880' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-887' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-888' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-892' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-895' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-906' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-905' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-909' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-914' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-918' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-921' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-924' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-830' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-825' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-819' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-814' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-811' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-762' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-769' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-771' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-773' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-776' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-784' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-808' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-804' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-792' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-787' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-939' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-953' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 5>()
#       3 df.known_divisions
#       4 df = df.set_index('t', sorted=True)
# ----> 5 df = df.set_index('i', sorted=True)
#       6 df = df.set_index('j', sorted=True)
#       7 df = df.set_index('k', sorted=True)
#
# File D:\anaconda\ana\lib\site-packages\dask\dataframe\core.py:4675, in DataFrame.set_index(***failed resolving arguments***)
#    4672 if pre_sorted:
#    4673     from dask.dataframe.shuffle import set_sorted_index
# -> 4675     return set_sorted_index(
#    4676         self, other, drop=drop, divisions=divisions, **kwargs
#    4677     )
#    4678 else:
#    4679     from dask.dataframe.shuffle import set_index
#
# File D:\anaconda\ana\lib\site-packages\dask\dataframe\shuffle.py:1082, in set_sorted_index(df, index, drop, divisions, **kwargs)
#    1071 result = map_partitions(
#    1072     M.set_index,
#    1073     df,
#    (...)
#    1078     transform_divisions=False,
#    1079 )
#    1081 if not divisions:
# -> 1082     return compute_and_set_divisions(result, **kwargs)
#    1083 elif len(divisions) != len(df.divisions):
#    1084     msg = (
#    1085         "When doing `df.set_index(col, sorted=True, divisions=...)`, "
#    1086         "divisions indicates known splits in the index column. In this "
#    (...)
#    1091         "`df.set_index(col, sorted=True).repartition(divisions=divisions)`"
#    1092     )
#
# File D:\anaconda\ana\lib\site-packages\dask\dataframe\shuffle.py:1056, in compute_and_set_divisions(df, **kwargs)
#    1055 def compute_and_set_divisions(df, **kwargs):
# -> 1056     mins, maxes, lens = _compute_partition_stats(df.index, allow_overlap=True, **kwargs)
#    1057     if len(mins) == len(df.divisions) - 1:
#    1058         df.divisions = tuple(mins) + (maxes[-1],)
#
# File D:\anaconda\ana\lib\site-packages\dask\dataframe\shuffle.py:1018, in _compute_partition_stats(column, allow_overlap, **kwargs)
#    1016 maxes = column.map_partitions(M.max, meta=column)
#    1017 lens = column.map_partitions(len, meta=column)
# -> 1018 mins, maxes, lens = compute(mins, maxes, lens, **kwargs)
#    1019 mins = remove_nans(mins)
#    1020 maxes = remove_nans(maxes)
#
# File D:\anaconda\ana\lib\site-packages\dask\base.py:575, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     572     keys.append(x.__dask_keys__())
#     573     postcomputes.append(x.__dask_postcompute__())
# --> 575 results = schedule(dsk, keys, **kwargs)
#     576 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File D:\anaconda\ana\lib\site-packages\distributed\client.py:3015, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3013         should_rejoin = False
#    3014 try:
# -> 3015     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3016 finally:
#    3017     for f in futures.values():
#
# File D:\anaconda\ana\lib\site-packages\distributed\client.py:2167, in Client.gather(self, futures, errors, direct, asynchronous)
#    2165 else:
#    2166     local_worker = None
# -> 2167 return self.sync(
#    2168     self._gather,
#    2169     futures,
#    2170     errors=errors,
#    2171     direct=direct,
#    2172     local_worker=local_worker,
#    2173     asynchronous=asynchronous,
#    2174 )
#
# File D:\anaconda\ana\lib\site-packages\distributed\utils.py:309, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     307     return future
#     308 else:
# --> 309     return sync(
#     310         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     311     )
#
# File D:\anaconda\ana\lib\site-packages\distributed\utils.py:372, in sync(loop, func, callback_timeout, *args, **kwargs)
#     370 else:
#     371     while not e.is_set():
# --> 372         wait(10)
#     374 if error:
#     375     typ, exc, tb = error
#
# File D:\anaconda\ana\lib\site-packages\distributed\utils.py:361, in sync.<locals>.wait(timeout)
#     359 def wait(timeout):
#     360     try:
# --> 361         return e.wait(timeout)
#     362     except KeyboardInterrupt:
#     363         loop.add_callback(cancel)
#
# File D:\anaconda\ana\lib\threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File D:\anaconda\ana\lib\threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
df.known_divisions
df.head()
df.info()
df.divisions
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 6 entries, t to q
# dtypes: float64(2), int64(4)
# (None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None)

# %% [markdown]
# ##In the year 2012, who were the top 10 countries with the most trading partners? What about the bottom 10?

# %%
df.loc[2012].compute()
len(df)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-147' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-168' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-165' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-174' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-179' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-182' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-185' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-187' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-190' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-193' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-132' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-137' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-142' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-145' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-151' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-156' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-162' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-166' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-169' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df.loc[2012].compute()
#       2 len(df)
#
# File D:\anaconda\ana\lib\site-packages\dask\base.py:292, in DaskMethodsMixin.compute(self, **kwargs)
#     268 def compute(self, **kwargs):
#     269     """Compute this dask collection
#     270
#     271     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     290     dask.base.compute
#     291     """
# --> 292     (result,) = compute(self, traverse=False, **kwargs)
#     293     return result
#
# File D:\anaconda\ana\lib\site-packages\dask\base.py:575, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     572     keys.append(x.__dask_keys__())
#     573     postcomputes.append(x.__dask_postcompute__())
# --> 575 results = schedule(dsk, keys, **kwargs)
#     576 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File D:\anaconda\ana\lib\site-packages\distributed\client.py:3015, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3013         should_rejoin = False
#    3014 try:
# -> 3015     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3016 finally:
#    3017     for f in futures.values():
#
# File D:\anaconda\ana\lib\site-packages\distributed\client.py:2167, in Client.gather(self, futures, errors, direct, asynchronous)
#    2165 else:
#    2166     local_worker = None
# -> 2167 return self.sync(
#    2168     self._gather,
#    2169     futures,
#    2170     errors=errors,
#    2171     direct=direct,
#    2172     local_worker=local_worker,
#    2173     asynchronous=asynchronous,
#    2174 )
#
# File D:\anaconda\ana\lib\site-packages\distributed\utils.py:309, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     307     return future
#     308 else:
# --> 309     return sync(
#     310         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     311     )
#
# File D:\anaconda\ana\lib\site-packages\distributed\utils.py:372, in sync(loop, func, callback_timeout, *args, **kwargs)
#     370 else:
#     371     while not e.is_set():
# --> 372         wait(10)
#     374 if error:
#     375     typ, exc, tb = error
#
# File D:\anaconda\ana\lib\site-packages\distributed\utils.py:361, in sync.<locals>.wait(timeout)
#     359 def wait(timeout):
#     360     try:
# --> 361         return e.wait(timeout)
#     362     except KeyboardInterrupt:
#     363         loop.add_callback(cancel)
#
# File D:\anaconda\ana\lib\threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File D:\anaconda\ana\lib\threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Task exception was never retrieved
# future: <Task finished name='Task-172' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-175' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-180' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-183' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-186' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-192' coro=<Client._gather.<locals>.wait() done, defined at D:\anaconda\ana\lib\site-packages\distributed\client.py:1999> exception=AllExit()>
# Traceback (most recent call last):
#   File "D:\anaconda\ana\lib\site-packages\distributed\client.py", line 2004, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
df12 = pd.read_csv("C:\\Users\\fxx\\Desktop\\zuoye\\ace 592 file\\BACI_HS12_Y2018_V202201.csv",nrows=100)
df12
# Out:
#        t  i   j       k        v       q
# 0   2018  4  24  845420  114.415  26.000
# 1   2018  4  24  848180    2.631   0.007
# 2   2018  4  31   80211    0.333   0.042
# 3   2018  4  31   80212    1.982   0.196
# 4   2018  4  31   80620    0.174   0.042
# ..   ... ..  ..     ...      ...     ...
# 95  2018  4  40  190590    0.039   0.022
# 96  2018  4  40  200811    0.011   0.003
# 97  2018  4  40  200899    0.020   0.013
# 98  2018  4  40  300590    2.036   0.024
# 99  2018  4  40  300650    4.091   0.050
#
# [100 rows x 6 columns]

# %%
import dask.dataframe as dd
df = dd.read_csv("C:\\Users\\fxx\\Desktop\\zuoye\\ace 592 file\\BACI_HS12_Y*.csv")
df
# Out:
# Dask DataFrame Structure:
#                     t      i      j      k        v        q
# npartitions=66
#                 int64  int64  int64  int64  float64  float64
#                   ...    ...    ...    ...      ...      ...
# ...               ...    ...    ...    ...      ...      ...
#                   ...    ...    ...    ...      ...      ...
#                   ...    ...    ...    ...      ...      ...
# Dask Name: read-csv, 66 tasks

# %%
import glob
glob.glob("C:\\Users\fxx\\Desktop\\zuoye\\ace 592 file\\BACI_HS12_Y*.csv")
# Out:
# []

# %%
df.loc[df.t==2012]
# Out:
# Dask DataFrame Structure:
#                     t      i      j      k        v        q
# npartitions=66
#                 int64  int64  int64  int64  float64  float64
#                   ...    ...    ...    ...      ...      ...
# ...               ...    ...    ...    ...      ...      ...
#                   ...    ...    ...    ...      ...      ...
#                   ...    ...    ...    ...      ...      ...
# Dask Name: loc-series, 264 tasks

# %%
df.loc[df.t==2012].groupby("q")['v'].mean().compute()
# Out:
# q
# 1.000000e-03    3.177572e+00
# 2.000000e-03    9.114683e+00
# 3.000000e-03    1.299101e+01
# 4.000000e-03    9.923463e+00
# 5.000000e-03    8.270749e+00
#                     ...
# 2.383759e+07    2.617528e+05
# 2.616867e+07    1.437417e+07
# 3.879811e+07    2.946513e+07
# 4.654537e+07    3.065698e+07
# 1.230284e+08    8.960144e+07
# Name: v, Length: 796001, dtype: float64

# %%
df_2012 = df.loc[2012]

# %%
top_12 = df_2012.v.value_counts().nlargest(10).compute()

# %%
top_12
# Out:
# 0.012        1
# 0.027        1
# 0.105        1
# 0.182        1
# 0.298        1
# 0.748        1
# 1.780        1
# 3.593        1
# 11955.493    1
# Name: v, dtype: int64

# %%
top_12df=top_12.to_frame()

# %%
top_12df_merged=top_12df.merge(value, how='left', right_index=True, left_index=True)\
.sort_values(by='v''q', ascending=False)
top_12df_merged

# %%
def most_exports(partition):
    # partition is a pandas.DataFrame
    country = partition.country.value_counts().nlargest(1).index[0]
    description = country_mapping.loc[minfd].minfddesc.iloc[0]
    year = int(partition.index[0])
    return pd.DataFrame({'year': [year], 'description': [description]})

# %%
country_year = df.map_partitions(most_exports, 
                              meta={'year': int,
                                    'description': str})

# %%
mnfd_year.compute()

# %%
products = pd.read_csv("C:\\Users\\fxx\\Desktop\\zuoye\\ace 592 file\\product_codes_HS12_V202201.csv")
products = products.rename(columns={"code":"k"})

# %%
products
# Out:
#            k                                        description
# 0      10121           Horses: live, pure-bred breeding animals
# 1      10129  Horses: live, other than pure-bred breeding an...
# 2      10130                                        Asses: live
# 3      10190                            Mules and hinnies: live
# 4      10221           Cattle: live, pure-bred breeding animals
# ...      ...                                                ...
# 5197  970300  Sculptures and statuary: original, in any mate...
# 5198  970400  Stamps, postage or revenue: stamp-postmarks, f...
# 5199  970500  Collections and collectors' pieces: of zoologi...
# 5200  970600    Antiques: of an age exceeding one hundred years
# 5201  999999        Commodities not specified according to kind
#
# [5202 rows x 2 columns]

# %%
df_wdes = df.merge(products)

# %%
countries = pd.read_csv("C:\\Users\\fxx\Desktop\\zuoye\\ace 592 file\\country_codes_V202201.csv",encoding = "ISO-8859-1")
countries = countries.rename(columns={"country_code":"i","country_name_full":"name_i"})
df_wdes = df_wdes.merge(countries[['i','name_i']])

countries = pd.read_csv("C:\\Users\\fxx\Desktop\\zuoye\\ace 592 file\\country_codes_V202201.csv",encoding = "ISO-8859-1")
countries = countries.rename(columns={"country_code":"j","country_name_full":"name_j"})
df_wdes = df_wdes.merge(countries[['j','name_j']])

# %%
df_wdes.head()
# Out:
#       t   i  j       k      v      q  \
# 0  2012   4  8  610469  2.734  0.044
# 1  2012   4  8  630900  0.110  0.082
# 2  2012  20  8  910211  2.314  0.003
# 3  2012  20  8  960810  0.144    NaN
# 4  2012  20  8   80510  1.457  2.228
#
#                                          description       name_i   name_j
# 0  Trousers, bib and brace overalls, breeches and...  Afghanistan  Albania
# 1            Clothing: worn, and other worn articles  Afghanistan  Albania
# 2  Wrist-watches: electrically operated, with or ...      Andorra  Albania
# 3                                   Pens: ball point      Andorra  Albania
# 4             Fruit, edible: oranges, fresh or dried      Andorra  Albania

# %%
df_wdes['avg_price'] = df_wdes['v']/df_wdes['q']

# %%
df_wdes.head(10)
# Out:
#       t   i  j       k       v       q  \
# 0  2012   4  8  610469   2.734   0.044
# 1  2012   4  8  630900   0.110   0.082
# 2  2012  20  8  910211   2.314   0.003
# 3  2012  20  8  960810   0.144     NaN
# 4  2012  20  8   80510   1.457   2.228
# 5  2012  28  8  170490   0.064   0.009
# 6  2012  28  8   80550   3.389   4.517
# 7  2012  28  8  200811   1.571   0.427
# 8  2012  28  8  190531   0.030   0.005
# 9  2012  28  8  230400  15.601  25.000
#
#                                          description               name_i  \
# 0  Trousers, bib and brace overalls, breeches and...          Afghanistan
# 1            Clothing: worn, and other worn articles          Afghanistan
# 2  Wrist-watches: electrically operated, with or ...              Andorra
# 3                                   Pens: ball point              Andorra
# 4             Fruit, edible: oranges, fresh or dried              Andorra
# 5  Sugar confectionery: (excluding chewing gum, i...  Antigua and Barbuda
# 6  Fruit, edible: lemons (Citrus limon, Citrus li...  Antigua and Barbuda
# 7  Nuts: ground-nuts, whether or not containing a...  Antigua and Barbuda
# 8  Food preparations: sweet biscuits, whether or ...  Antigua and Barbuda
# 9  Oil-cake and other solid residues: whether or ...  Antigua and Barbuda
#
#     name_j   avg_price
# 0  Albania   62.136364
# 1  Albania    1.341463
# 2  Albania  771.333333
# 3  Albania         NaN
# 4  Albania    0.653950
# 5  Albania    7.111111
# 6  Albania    0.750277
# 7  Albania    3.679157
# 8  Albania    6.000000
# 9  Albania    0.624040

# %%
avg12 = df_wdes.loc[df_wdes.t==2012]['avg_price']

# %%
ex = avg12.compute()

# %%
ex
# Out:
# 0           62.136364
# 1            1.341463
# 2          771.333333
# 3                 NaN
# 4            0.653950
#               ...
# 1489110    302.526891
# 1489111      2.634867
# 1489112      1.936972
# 1489113     11.176256
# 1489114      2.454607
# Name: avg_price, Length: 8977423, dtype: float64

# %%
avg12.mean().compute()
# Out:
# 2022-04-27 13:42:09,877 - distributed.worker_memory - WARNING - Worker exceeded 95% memory budget. Restarting
# 2022-04-27 13:42:10,000 - distributed.nanny - WARNING - Restarting worker

# %%
avg12.var().compute()

# %%
product_counts = df['k'].value_counts().compute()

product_dict = products.set_index("k")['description'].to_dict()

product_counts.index=  pd.Series(product_counts.index).replace(product_dict)

# %%
product_counts.head(10)
# Out:
# Plastics: other articles n.e.c. in chapter 39                                                                                                                                                                             117540
# Iron or steel: articles n.e.c.in heading 7326                                                                                                                                                                             102137
# Printed matter: books, brochures, leaflets and similar printed matter n.e.c. in item no. 4901.10 or 4901.91                                                                                                                93445
# T-shirts, singlets and other vests: of cotton, knitted or crocheted                                                                                                                                                        92834
# Electrical static converters                                                                                                                                                                                               92771
# Vehicle parts and accessories: n.e.c. in heading no. 8708                                                                                                                                                                  92214
# Rubber: vulcanised (other than hard rubber), gaskets, washers and other seals, of non-cellular rubber                                                                                                                      88414
# Communication apparatus (excluding telephone sets or base stations): machines for the reception, conversion and transmission or regeneration of voice, images or other data, including switching and routing apparatus     88356
# Taps, cocks, valves and similar appliances: for pipes, boiler shells, tanks, vats or the like, including thermostatically controlled valves                                                                                86790
# Food preparations: n.e.c. in item no. 2106.10                                                                                                                                                                              86776
# Name: k, dtype: int64

# %%
df['q'].nlargest(10).compute()
# Out:
# 1336879    7.059573e+08
# 90921      6.965135e+08
# 117372     6.924810e+08
# 108906     6.868821e+08
# 121201     6.857592e+08
# 109270     6.776354e+08
# 113560     6.497960e+08
# 1431949    6.115246e+08
# 98624      5.912236e+08
# 1563422    5.808956e+08
# Name: q, dtype: float64

# %%
country_v_sums = df.groupby("i")['v'].sum().compute()

# %%
country_v_sums.sort_values(ascending=False)
# Out:
# i
# 156    2.249401e+10
# 842    1.319568e+10
# 276    1.223787e+10
# 392    6.673620e+09
# 410    5.191421e+09
#            ...
# 500    2.891476e+04
# 574    2.670580e+04
# 612    1.796377e+04
# 876    9.984833e+03
# 530    2.722692e+03
# Name: v, Length: 228, dtype: float64

# %% [markdown]
# ### An analyst asks you "for which commodity sectors is distance most important in terms of exporting?" Describe what your economic intuition would say about the answer, and then also map out an analysis strategy for answering their question.

# %% [markdown]
# First of all, to solve the problem, the data I need is the data about the countries exporting bulk commodities, the specific classification and proportion of export products. At the same time, it also needs the distance requirements of the exporting countries and the economic organization structure of the exporting countries, so as to judge the country's tolerance and demand for imported products.

# %% [markdown]
# For the use of data, I will follow two aspects: the use of direct evidence and the auxiliary verification of indirect evidence. Therefore, I will first gather direct evidence, including the content and quantity of exports and the proportion of exports in the national GDP, while indirect evidence means the total economic volume, economic structure and import proportion of the exported country, so as to judge whether it can be used as a high-quality cooperative trade object.
